# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.spotify.music',
    lang='pl', # defaults to 'en'
    country='pl', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    count=200, # defaults to 100
    filter_score_with=None # defaults to None(means all score)
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.spotify.music',
    continuation_token=None # defaults to None(load from the beginning)
)

# %%
print(result)
# Out:
# [{'userName': 'Jason Qualkinbush', 'userImage': 'https://lh3.googleusercontent.com/-yCURXGdcqbI/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJNJ4Jy2H8gdzKv5b_zzepvNjJ_Rig/photo.jpg', 'content': 'Love it better than I heart radio', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '8.5.54.869', 'at': datetime.datetime(2020, 4, 25, 12, 38, 45), 'replyContent': None, 'repliedAt': None}, {'userName': 'Sanjay Jain', 'userImage': 'https://lh3.googleusercontent.com/-BBfX_Hr0taY/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJNIIyYIgWe6PHHkSJvQtGE1EKUM1g/photo.jpg', 'content': 'Good', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '8.5.54.869', 'at': datetime.datetime(2020, 4, 25, 12, 37, 59), 'replyContent': None, 'repliedAt': None}, {'userName': 'ateeq zaman', 'userImage': 'https://lh3.googleusercontent.com/-OQZd1JFqjqA/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJNyBDuPfmf3HY_wqJZKHCTqx8ZArA/photo.jpg', 'content': 'I like this app', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '8.5.54.869', 'at': datetime.datetime(2020, 4, 25, 12, 37, 21), 'replyContent': None, 'repliedAt': None}, {'userName': 'yohan outsider', 'userImage': 'https://lh3.googleusercontent.com/a-/AOh14GiW6j6GrGJnqF3FT3kJ-KiHHwHb30IeIvVvx4dBLg', 'content': "Why you didn't give lyrics , meanwhile apple music did.... Will get 5 star, if could support move to sd card", 'score': 4, 'thumbsUpCount': 0, 'reviewCreatedVersion': '8.5.51.941', 'at': datetime.datetime(2020, 4, 25, 12, 37, 19), 'replyContent': None, 'repliedAt': None}, {'userName': 'Raheema Epino', 'userImage': 'https://lh3.googleusercontent.com/-t0JXDVrhV5c/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJP29ELGSUoyEjuvMvozDTAgUfRREA/photo.jpg', 'content': 'This is so amazing I can listen to my fav. Songs...love it.....', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': None, 'at': datetime.datetime(2020, 4, 25, 12, 37, 1), 'replyContent': None, 'repliedAt': None}, {'userName': 'Ivan Erya Novandre', 'userImage': 'https://lh3.googleusercontent.com/a-/AOh14GjMC0PcAloV4ZBiIKlSQ50XLIuW45DrK_2mHU5Kxw0', 'content': 'Great app', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '8.5.54.869', 'at': datetime.datetime(2020, 4, 25, 12, 34, 5), 'replyContent': None, 'repliedAt': None}, {'userName': 'Anushka Gundemoni', 'userImage': 'https://lh3.googleusercontent.com/-beLBn39Xp_c/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJNBIJita6PRYr2aAlC9do9oW-mabQ/photo.jpg', 'content': 'Best app i hv ever found', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': None, 'at': datetime.datetime(2020, 4, 25, 12, 33, 55), 'replyContent': None, 'repliedAt': None}, {'userName': 'Archit Mestry', 'userImage': 'https://lh3.googleusercontent.com/a-/AOh14GjLnGH285n984fxgqEiCGjv6cHYDqvb-VgFTYfhAw', 'content': 'Too many ads and less artists and more loading time... Spotify is degrading after updates', 'score': 1, 'thumbsUpCount': 0, 'reviewCreatedVersion': '8.5.51.941', 'at': datetime.datetime(2020, 4, 25, 12, 33, 11), 'replyContent': None, 'repliedAt': None}, {'userName': 'Damir Velickovic', 'userImage': 'https://lh3.googleusercontent.com/-sNJUMX2iEjQ/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJPYB5SZ7IO1CAFXzarJePX5FxZ5Hg/photo.jpg', 'content': "i can't create a new account", 'score': 1, 'thumbsUpCount': 0, 'reviewCreatedVersion': '8.5.54.869', 'at': datetime.datetime(2020, 4, 25, 12, 33, 10), 'replyContent': None, 'repliedAt': None}, {'userName': 'Johanna Mellet', 'userImage': 'https://lh3.googleusercontent.com/-Q-WLVvM1594/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJMmBZzcvX3sxVYcuXVQGmDKcNMpgw/photo.jpg', 'content': 'Love this', 'score': 4, 'thumbsUpCount': 0, 'reviewCreatedVersion': '8.5.51.941', 'at': datetime.datetime(2020, 4, 25, 12, 31, 16), 'replyContent': None, 'repliedAt': None}, {'userName': 'Adrian Davis', 'userImage': 'https://lh3.googleusercontent.com/-utDwM83PkRw/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJMpYCIgucRianCc7ShPHTeyyLoA-Q/photo.jpg', 'content': 'Great, except for disconnecting from Chromecast all the time', 'score': 2, 'thumbsUpCount': 0, 'reviewCreatedVersion': '8.5.54.869', 'at': datetime.datet ...

# %%
df_google_play_spotify = pd.DataFrame(result)
df_google_play_spotify.to_csv('df_google_play_spotify.csv')
